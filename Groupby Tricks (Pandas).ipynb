# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import random
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('zomato.csv',encoding='latin-1',skipinitialspace=True)
df_country=pd.read_excel('Country-Code.xlsx')
df=pd.merge(df,df_country,on='Country Code',how='left')
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
#
#   Is delivering now Switch to order menu Price range Aggregate rating  \
# 0                No                   No           3              4.8
#
#    Rating color  Rating text Votes      Country
# 0    Dark Green    Excellent   314  Phillipines
#
# [1 rows x 22 columns]

# %%
df.groupby(['Country'])

# %%
df['Country'].nunique()
# Out:
# 15

# %%
df.groupby('Country').ngroups
# Out:
# 15

# %%
df.groupby('Country').size()
# Out:
# Country
# Australia           24
# Brazil              60
# Canada               4
# India             8652
# Indonesia           21
# New Zealand         40
# Phillipines         22
# Qatar               20
# Singapore           20
# South Africa        60
# Sri Lanka           20
# Turkey              34
# UAE                 60
# United Kingdom      80
# United States      434
# dtype: int64

# %%
df['Country'].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
df.groupby('Country').count()
# Out:
#                 Restaurant ID  Restaurant Name  Country Code  City  Address  \
# Country
# Australia                  24               24            24    24       24
# Brazil                     60               60            60    60       60
# Canada                      4                4             4     4        4
# India                    8652             8652          8652  8652     8652
# Indonesia                  21               21            21    21       21
# New Zealand                40               40            40    40       40
# Phillipines                22               22            22    22       22
# Qatar                      20               20            20    20       20
# Singapore                  20               20            20    20       20
# South Africa               60               60            60    60       60
# Sri Lanka                  20               20            20    20       20
# ...

# %%
df.groupby('Country').first()
# Out:
#                 Restaurant ID              Restaurant Name  Country Code  \
# Country
# Australia            16611114              Whitebull Hotel            14
# Brazil                6600681                  Chez Michou            30
# Canada               16659169                  Tokyo Sushi            37
# India                 3400025                   Jahanpanah             1
# Indonesia            18400530       Noah's Barn Coffeenery            94
# New Zealand          18251260                    Kiss Kiss           148
# Phillipines           6317637             Le Petit Souffle           162
# Qatar                18426586         7st by Mumbai Spices           166
# Singapore            18483372                    Sky On 57           184
# South Africa         18395463           The Butcher's Wife           189
# Sri Lanka             5800557          Chinese Dragon Cafe           191
# Turkey                6001980                  Timboo Cafe           208
# ...

# %%
df.groupby('Country').last()
# Out:
#                 Restaurant ID                          Restaurant Name  \
# Country
# Australia            16608209       Anchorage Cafe Restaurant Wine Bar
# Brazil                6713772                 Sainte Marie Gastronomia
# Canada               16668008                            Arigato Sushi
# India                 2800019                 Flying Spaghetti Monster
# Indonesia             7417450                         Talaga Sampireun
# New Zealand           7100788                           The Crab Shack
# Phillipines           6310406            The Food Hall by Todd English
# Qatar                18318801                              Roti & Boti
# Singapore            18483252                           Artichoke Cafe
# South Africa          6502857                      Remo's Maximilliano
# Sri Lanka             5800612                            Burger's King
# Turkey                5927402                 Walter's Coffee Roastery
# ...

# %%
df.groupby('Country').nth(8)
# Out:
#                 Restaurant ID                           Restaurant Name  \
# Country
# Australia            16604896                 La Trattoria of Lavandula
# Brazil                6600060                            Sandubas Cafí©
# India                 3400348                                    G Thal
# Indonesia             7410290                  Satoo - Hotel Shangri-La
# New Zealand          18419011                        The Kimchi Project
# Phillipines           6300010  Spiral - Sofitel Philippine Plaza Manila
# Qatar                 6201336                                 Ponderosa
# Singapore            18485469                       Boufe Boutique Cafe
# South Africa          6403291                        Jerry's Burger Bar
# Sri Lanka             5800718              Simply Strawberries By Jagro
# Turkey                6000409                                   Cafemiz
# UAE                   5702418                                    Gazebo
# ...

# %%
for name_of_group, contents_of_group in df.groupby('Country'):
    print(name_of_group)
    print(contents_of_group)
# Out:
# Australia
#      Restaurant ID                     Restaurant Name  Country Code  \
# 102       16611114                     Whitebull Hotel            14
# 143       16608864                   Taste of Balingup            14
# 144       16604911                 Bridge Road Brewers            14
# 269       16615894                   The Giggling Goat            14
# 290       16612028                   The Belle General            14
# 292       16613507                     Flaxton Gardens            14
# 293       16607969                     Bespoke Harvest            14
# 314       16604358                 Blue Bean Love Cafe            14
# 315       16604896           La Trattoria of Lavandula            14
# 316       16612550                       5 Little Pigs            14
# 317       16606299                      Beach Box Cafe            14
# 318       16605794                       Funkey Monkey            14
# ...

# %%
df.groupby('Country')[['Price range','Votes']].mean()
# Out:
#                 Price range       Votes
# Country
# Australia          2.125000  111.416667
# Brazil             3.400000   19.616667
# Canada             2.500000  103.000000
# India              1.721683  137.212552
# Indonesia          2.952381  772.095238
# New Zealand        3.150000  243.025000
# Phillipines        3.363636  407.409091
# Qatar              3.650000  163.800000
# Singapore          3.650000   31.900000
# South Africa       3.583333  315.166667
# Sri Lanka          2.850000  146.450000
# Turkey             2.823529  431.470588
# UAE                3.216667  493.516667
# United Kingdom     2.750000  205.487500
# United States      2.046083  428.221198

# %%
df.groupby('Country')[['Price range','Votes']].aggregate('mean')
# Out:
#                 Price range       Votes
# Country
# Australia          2.125000  111.416667
# Brazil             3.400000   19.616667
# Canada             2.500000  103.000000
# India              1.721683  137.212552
# Indonesia          2.952381  772.095238
# New Zealand        3.150000  243.025000
# Phillipines        3.363636  407.409091
# Qatar              3.650000  163.800000
# Singapore          3.650000   31.900000
# South Africa       3.583333  315.166667
# Sri Lanka          2.850000  146.450000
# Turkey             2.823529  431.470588
# UAE                3.216667  493.516667
# United Kingdom     2.750000  205.487500
# United States      2.046083  428.221198

# %%
df.groupby('Country').aggregate({'Price range':'mean','Votes':'count'})
# Out:
#                 Price range  Votes
# Country
# Australia          2.125000     24
# Brazil             3.400000     60
# Canada             2.500000      4
# India              1.721683   8652
# Indonesia          2.952381     21
# New Zealand        3.150000     40
# Phillipines        3.363636     22
# Qatar              3.650000     20
# Singapore          3.650000     20
# South Africa       3.583333     60
# Sri Lanka          2.850000     20
# Turkey             2.823529     34
# UAE                3.216667     60
# United Kingdom     2.750000     80
# United States      2.046083    434

# %%
df.groupby(['Country']).get_group('Australia')
# Out:
#      Restaurant ID                     Restaurant Name  Country Code  \
# 102       16611114                     Whitebull Hotel            14
# 143       16608864                   Taste of Balingup            14
# 144       16604911                 Bridge Road Brewers            14
# 269       16615894                   The Giggling Goat            14
# 290       16612028                   The Belle General            14
# 292       16613507                     Flaxton Gardens            14
# 293       16607969                     Bespoke Harvest            14
# 314       16604358                 Blue Bean Love Cafe            14
# 315       16604896           La Trattoria of Lavandula            14
# 316       16612550                       5 Little Pigs            14
# 317       16606299                      Beach Box Cafe            14
# 318       16605794                       Funkey Monkey            14
# 321       16611498               Stillwater on Belmore            14
# ...

# %%
df[df['Country']=='Australia']
# Out:
#      Restaurant ID                     Restaurant Name  Country Code  \
# 102       16611114                     Whitebull Hotel            14
# 143       16608864                   Taste of Balingup            14
# 144       16604911                 Bridge Road Brewers            14
# 269       16615894                   The Giggling Goat            14
# 290       16612028                   The Belle General            14
# 292       16613507                     Flaxton Gardens            14
# 293       16607969                     Bespoke Harvest            14
# 314       16604358                 Blue Bean Love Cafe            14
# 315       16604896           La Trattoria of Lavandula            14
# 316       16612550                       5 Little Pigs            14
# 317       16606299                      Beach Box Cafe            14
# 318       16605794                       Funkey Monkey            14
# 321       16611498               Stillwater on Belmore            14
# ...

# %%
df.loc[df['Country']=='Australia']
# Out:
#      Restaurant ID                     Restaurant Name  Country Code  \
# 102       16611114                     Whitebull Hotel            14
# 143       16608864                   Taste of Balingup            14
# 144       16604911                 Bridge Road Brewers            14
# 269       16615894                   The Giggling Goat            14
# 290       16612028                   The Belle General            14
# 292       16613507                     Flaxton Gardens            14
# 293       16607969                     Bespoke Harvest            14
# 314       16604358                 Blue Bean Love Cafe            14
# 315       16604896           La Trattoria of Lavandula            14
# 316       16612550                       5 Little Pigs            14
# 317       16606299                      Beach Box Cafe            14
# 318       16605794                       Funkey Monkey            14
# 321       16611498               Stillwater on Belmore            14
# ...

# %%
df.groupby('Country')[['Price range','Votes']].count()
# Out:
#                 Price range  Votes
# Country
# Australia                24     24
# Brazil                   60     60
# Canada                    4      4
# India                  8652   8652
# Indonesia                21     21
# New Zealand              40     40
# Phillipines              22     22
# Qatar                    20     20
# Singapore                20     20
# South Africa             60     60
# Sri Lanka                20     20
# Turkey                   34     34
# UAE                      60     60
# United Kingdom           80     80
# United States           434    434

# %%
df.groupby('Country')[['Price range','Votes']].size()
# Out:
# Country
# Australia           24
# Brazil              60
# Canada               4
# India             8652
# Indonesia           21
# New Zealand         40
# Phillipines         22
# Qatar               20
# Singapore           20
# South Africa        60
# Sri Lanka           20
# Turkey              34
# UAE                 60
# United Kingdom      80
# United States      434
# dtype: int64

# %%
df.groupby('Country')[['Price range']].describe()
# Out:
#                Price range
#                      count      mean       std  min  25%  50%   75%  max
# Country
# Australia             24.0  2.125000  0.740887  1.0  2.0  2.0  2.25  4.0
# Brazil                60.0  3.400000  0.827494  1.0  3.0  4.0  4.00  4.0
# Canada                 4.0  2.500000  1.000000  2.0  2.0  2.0  2.50  4.0
# India               8652.0  1.721683  0.852544  1.0  1.0  2.0  2.00  4.0
# Indonesia             21.0  2.952381  0.218218  2.0  3.0  3.0  3.00  3.0
# New Zealand           40.0  3.150000  0.892993  1.0  3.0  3.0  4.00  4.0
# Phillipines           22.0  3.363636  0.581087  2.0  3.0  3.0  4.00  4.0
# Qatar                 20.0  3.650000  0.587143  2.0  3.0  4.0  4.00  4.0
# Singapore             20.0  3.650000  0.587143  2.0  3.0  4.0  4.00  4.0
# South Africa          60.0  3.583333  0.618683  2.0  3.0  4.0  4.00  4.0
# Sri Lanka             20.0  2.850000  0.670820  2.0  2.0  3.0  3.00  4.0
# ...

# %%
df.groupby('Country')['Price range'].size().reset_index(drop=False)
# Out:
#            Country  Price range
# 0        Australia           24
# 1           Brazil           60
# 2           Canada            4
# 3            India         8652
# 4        Indonesia           21
# 5      New Zealand           40
# 6      Phillipines           22
# 7            Qatar           20
# 8        Singapore           20
# 9     South Africa           60
# 10       Sri Lanka           20
# 11          Turkey           34
# 12             UAE           60
# 13  United Kingdom           80
# 14   United States          434

# %%
df.groupby('Country')['Price range'].size().reset_index(drop=True)
# Out:
# 0       24
# 1       60
# 2        4
# 3     8652
# 4       21
# 5       40
# 6       22
# 7       20
# 8       20
# 9       60
# 10      20
# 11      34
# 12      60
# 13      80
# 14     434
# Name: Price range, dtype: int64

# %%
df.groupby('Country')['Price range'].size()
# Out:
# Country
# Australia           24
# Brazil              60
# Canada               4
# India             8652
# Indonesia           21
# New Zealand         40
# Phillipines         22
# Qatar               20
# Singapore           20
# South Africa        60
# Sri Lanka           20
# Turkey              34
# UAE                 60
# United Kingdom      80
# United States      434
# Name: Price range, dtype: int64

# %%
df.groupby('Country')[['Price range']].size()
# Out:
# Country
# Australia           24
# Brazil              60
# Canada               4
# India             8652
# Indonesia           21
# New Zealand         40
# Phillipines         22
# Qatar               20
# Singapore           20
# South Africa        60
# Sri Lanka           20
# Turkey              34
# UAE                 60
# United Kingdom      80
# United States      434
# dtype: int64
